# %%
import pandas as pd

# %%
dataset=pd.read_csv("Hit or Flop movie Dataset.csv")
dataset
# Out:
#     S.No Film Industry                      Movie Name      Genre  \
# 0      1     Kollywood                          Vikram     Action
# 1      2     Kollywood                          Sardar     Action
# 2      3     Kollywood                           Beast     Action
# 3      4     Kollywood                           Pizza     Horror
# 4      5     Kollywood  Naduvula Konjum Pakkatha kanum     Comedy
# 5      6     Kollywood                            Don      Comedy
# 6      7     Kollywood                          Doctor     Action
# 7      8     Kollywood               Ponniyin selvan-1     Action
# 8      9     Kollywood                        Maanaadu     Action
# 9     10     Kollywood                          Master     Action
# 10    11     Kollywood                 Soorarai pottru      Drama
# 11    12     Kollywood         Theeran Adhigaram ondru     Action
# 12    13     Kollywood               Ka Pae Ranasingam      Drama
# 13    14     Kollywood                          Karnan     Action
# 14    15     Kollywood                          Asuran     Action
# 15    16     Kollywood                             2.0     Action
# 16    17     Kollywood                              24     Action
# 17    18     Kollywood                English vinglish     Comedy
# 18    19     Kollywood                     Viswaroopam     Action
# 19    20     Kollywood                         Kaththi     Action
# 20    21     Kollywood                        Mahanati      Drama
# 21    22     Kollywood         Baahubali-The beginning     Action
# 22    23     Kollywood                        Enthiran     Action
# 23    24     Kollywood                    Kakka muttai     Comedy
# 24    25     Kollywood                        Jai Bhim      Drama
# 25    26     Kollywood               Aayirathil Oruvan     Action
# 26    27     Kollywood                             NGK     Action
# 27    28     Kollywood                          Bhoomi     Action
# 28    29     Kollywood                         Thodari     Action
# 29    30     Kollywood                          Prince     Comedy
# 30    31     Kollywood                      Seema Raja     Action
# 31    32     Kollywood                    Saamy Square     Action
# 32    33     Kollywood                             Dev     Action
# 33    34     Kollywood                            Puli     Action
# 34    35     Kollywood                         Adhavan     Action
# 35    36     Kollywood                    Alex pandian     Action
# 36    37     Kollywood                        Naiyandi     Comedy
# 37    38     Kollywood                  Manmadhan Ambu     Comedy
# 38    39     Kollywood                            Sura     Action
# 39    40     Kollywood                            Asal     Action
# 40    41     Kollywood                           Rekka     Action
# 41    42     Kollywood                       Vanamagan     Action
# 42    43     Kollywood                            Hero  Superhero
# 43    44     Kollywood                          Action     Action
# 44    45     Kollywood                         Ravanan     Action
# 45    46     Kollywood                           Cobra     Action
# 46    47     Kollywood                       Mappillai     Action
# 47    48     Kollywood                   Uttama villan     Comedy
# 48    49     Kollywood                     Kochadaiyan     Action
# 49    50     Kollywood                          Anjaan     Action
#
#    Movie Release Date Investment  Investment.1     Profit    Profit.1  \
# 0          03-06-2022  450 Crore    4500000000  150 Crore  1500000000
# 1          21-10-2022   40 Crore     400000000  100 Crore  1000000000
# 2          13-04-2022  150 Crore    1500000000  250 Crore  2500000000
# 3          19-10-2012  1.5 Crore      15000000    8 Crore    80000000
# 4          30-11-2012  0.8 Crore       8000000   18 Crore   180000000
# 5          13-05-2022    5 Crore      50000000  100 Crore  1000000000
# 6          09-10-2021   40 Crore     400000000  100 Crore  1000000000
# 7          30-09-2022  500 Crore    5000000000  495 Crore  4950000000
# 8          25-11-2021   30 Crore     300000000  117 Crore  1170000000
# 9          13-01-2021  135 Crore    1350000000  300 Crore  3000000000
# 10         12-11-2020   20 Crore     200000000  174 Crore  1740000000
# 11         17-11-2017   50 Crore     500000000   85 Crore   850000000
# 12         02-10-2020   10 Crore     100000000    9 Crore    90000000
# 13         09-04-2021   10 Crore     100000000   63 Crore   630000000
# 14         04-10-2019   32 Crore     320000000  155 Crore  1550000000
# 15         29-11-2018  600 Crore    6000000000  800 Crore  8000000000
# 16         06-05-2016   70 Crore     700000000  100 Crore  1000000000
# 17         05-10-2012   10 Crore     100000000  102 Crore  1020000000
# 18         07-02-2013   95 Crore     950000000  220 Crore  2200000000
# 19         22-10-2014   70 Crore     700000000  130 Crore  1300000000
# 20         09-05-2018   25 Crore     250000000   83 Crore   830000000
# 21         10-07-2015  180 Crore    1800000000  650 Crore  6500000000
# 22         01-10-2010  150 Crore    1500000000  290 Crore  2900000000
# 23         05-06-2015    1 Crore      10000000   12 Crore   120000000
# 24         02-11-2021   40 Crore     400000000  100 Crore  1000000000
# 25         14-01-2010   18 Crore     180000000   10 Crore   100000000
# 26         31-05-2019   65 Crore     650000000   30 Crore   300000000
# 27         14-01-2021   30 Crore     300000000   15 Crore   150000000
# 28         22-09-2016   40 Crore     400000000   23 Crore   230000000
# 29         21-10-2022   60 Crore     600000000   22 Crore   220000000
# 30         13-09-2018   60 Crore     600000000   49 Crore   490000000
# 31         21-09-2018   50 Crore     500000000   38 Crore   380000000
# 32         14-02-2019   40 Crore     400000000   25 Crore   250000000
# 33         01-10-2015  130 Crore    1300000000  100 Crore  1000000000
# 34         17-10-2009   30 Crore     300000000   20 Crore   200000000
# 35         11-01-2013   17 Crore     170000000   12 Crore   120000000
# 36         11-10-2013   20 Crore     200000000   16 Crore   160000000
# 37         22-12-2010   50 Crore     500000000   30 Crore   300000000
# 38         30-04-2010   30 Crore     300000000   40 Crore   400000000
# 39         05-02-2010   22 Crore     220000000   12 Crore   120000000
# 40         07-10-2016   10 Crore     100000000   14 Crore   140000000
# 41         23-06-2017   18 Crore     180000000   10 Crore   100000000
# 42         20-12-2019   45 Crore     450000000   40 Crore   400000000
# 43         15-11-2019   40 Crore     400000000   35 Crore   350000000
# 44         18-06-2010   55 Crore     550000000   50 Crore   500000000
# 45         31-08-2022  100 Crore    1000000000   60 Crore   600000000
# 46         08-04-2011   33 Crore     330000000   32 Crore   320000000
# 47         02-05-2015   50 Crore     500000000   26 Crore   260000000
# 48         23-05-2014  125 Crore    1250000000   42 Crore   420000000
# 49         15-08-2014   75 Crore     750000000   45 Crore   450000000
#
#     Success/Failure  ...  Pre-released song views.1 first song released date  \
# 0                 1  ...                   98000000               15-05-2022
# 1                 1  ...                    4000000               18-11-2022
# 2                 1  ...                   33000000               14-02-2022
# 3                 1  ...                     176000               06-09-2012
# 4                 1  ...                      49000               27-06-2012
# 5                 1  ...                   98000000               16-12-2021
# 6                 1  ...                   34000000               02-10-2021
# 7                 1  ...                   62000000               31-07-2022
# 8                 1  ...                   38000000               21-06-2021
# 9                 1  ...                  112000000               15-03-2020
# 10                1  ...                   16000000               24-01-2020
# 11                1  ...                      40000               13-11-2017
# 12                1  ...                     100000               10-10-2020
# 13                1  ...                   21000000               19-02-2021
# 14                1  ...                   23000000               18-09-2021
# 15                1  ...                   14000000               27-10-2017
# 16                1  ...                    2000000               10-02-2016
# 17                1  ...                    4100000               14-09-2012
# 18                1  ...                     350000               11-02-2013
# 19                1  ...                    1200000               17-10-2014
# 20                1  ...                    1200000               01-05-2018
# 21                1  ...                    1800000               07-06-2015
# 22                1  ...                    6000000               31-07-2010
# 23                1  ...                     150000               04-05-2015
# 24                1  ...                   19000000               30-10-2021
# 25                0  ...                     148000               04-06-2009
# 26                0  ...                    1000000               19-04-2019
# 27                0  ...                    2000000               18-10-2020
# 28                0  ...                    2100000               06-06-2016
# 29                0  ...                    1000000               30-09-2022
# 30                0  ...                   31000000               13-09-2018
# 31                0  ...                    2400000               10-07-2018
# 32                0  ...                    2000000               07-02-2019
# 33                0  ...                   11000000               02-08-2015
# 34                0  ...                    5000000               20-08-2009
# 35                0  ...                     225000               12-12-2012
# 36                0  ...                    1300000               17-09-2013
# 37                0  ...                     440000               25-11-2010
# 38                0  ...                      12000               25-04-2010
# 39                0  ...                      34000               20-01-2010
# 40                0  ...                    2000000               30-09-2016
# 41                0  ...                    2000000               22-04-2017
# 42                0  ...                    2800000               29-11-2019
# 43                0  ...                    4200000               09-11-2019
# 44                0  ...                    2000000               07-05-2010
# 45                0  ...                    6200000               09-08-2022
# 46                0  ...                   30000000               30-03-2011
# 47                0  ...                     657000               01-03-2015
# 48                0  ...                    1000000               09-03-2014
# 49                0  ...                   16000000               10-08-2014
#
#    YouTube Views.2  YouTube Views.3       OTT  Rating_Type  Meme Marketing  \
# 0       50 Million         50000000  Netflix          Good             yes
# 1       11 Million         11000000  Netflix          Good             yes
# 2       48 Million         48000000  Netflix       Average             yes
# 3     250 Thousand           250000   Netflix         Good             yes
# 4      30 Thousand            30000   Netflix         Good             Yes
# 5       47 Million         47000000   Netflix         Good             yes
# 6       41 Million         41000000   Netflix         Good             yes
# 7       50 Million         50000000   Netflix    Very good             Yes
# 8       18 Million         18000000   Netflix         Good             Yes
# 9      406 Million        406000000   Netflix         Good             yes
# 10      85 Million         85000000   Netflix         Good             yes
# 11   12.9 Thousand            12900   Netflix         Good             yes
# 12     8.3 Million          8300000   Netflix         Good             yes
# 13    19.5 Million         19500000   Netflix         Good             yes
# 14      32 Million         32000000   Netflix         Good             yes
# 15     7.9 Million          7900000   Netflix         Good             yes
# 16       8 Million          8000000   Netflix         Good             yes
# 17       3 Million          3000000   Netflix         Good             yes
# 18     6.8 Million          6800000   Netflix         Good             yes
# 19    587 Thousand           587000   Netflix         Good             yes
# 20    101 Thousand           101000   Netflix         Good             yes
# 21    19.5 Million        195000000   Netflix         Good             yes
# 22     1.4 Million          1400000   Netflix         Good             yes
# 23    451 Thousand           451000   Netflix         Good             yes
# 24      17 Million         17000000   Netflix         Good             yes
# 25    164 Thousand           164000   Netflix         Good             yes
# 26     2.9 Million          2900000   Netflix          Bad             yes
# 27       4 Million          4000000   Netflix          Bad             yes
# 28     7.4 Million          7400000   Netflix          Bad             yes
# 29      27 Million         27000000   Netflix          Bad             yes
# 30      73 Million         73000000   Netflix          Bad             yes
# 31      93 Million         93000000   Netflix          Bad             yes
# 32     4.6 Million          4600000   Netflix          Bad             yes
# 33      23 Million         23000000   Netflix          Bad             yes
# 34     17 Thousand            17000   Netflix          Bad             yes
# 35     5.6 Million          5600000   Netflix          Bad             yes
# 36     3.2 Million          3200000   Netflix          Bad             yes
# 37      20 Million         20000000   Netflix          Bad             yes
# 38      10 Million         10000000   Netflix          Bad             yes
# 39    100 Thousand           100000   Netflix          Bad             yes
# 40       7 Million          7000000   Netflix          Bad             yes
# 41      12 Million         12000000   Netflix          Bad             yes
# 42      30 Million         30000000   Netflix          Bad             yes
# 43     5.4 Million          5400000   Netflix          Bad             yes
# 44      38 Million         38000000   Netflix          Bad             yes
# 45      29 Million         29000000   Netflix          Bad             yes
# 46     4.4 Million          4400000   Netflix          Bad             yes
# 47       2 Million          2000000   Netflix          Bad             yes
# 48      13 Million         13000000   Netflix          Bad             yes
# 49      16 Million         16000000   Netflix          Bad             yes
#
#     Critics_from_people   First day Box office collection  \
# 0                   Good                         33 Crore
# 1                   Good                        3.7 Crore
# 2                Average                         40 Crore
# 3                   Good                        1.5 Crore
# 4                   Good                          5 Crore
# 5                   Good                         15 Crore
# 6                   Good                          8 Crore
# 7              Very Good                         34 Crore
# 8                   Good                          8 Crore
# 9                   Good                         18 Crore
# 10                  Good                          8 Crore
# 11                  Good                         10 Crore
# 12                  Good                          8 Crore
# 13                  Good                         10 Crore
# 14                  Good                         10 Crore
# 15                  Good                         82 Crore
# 16                  Good                         33 Crore
# 17                  Good                        2.5 Crore
# 18                  Good                         10 Crore
# 19                  Good                         15 Crore
# 20                  Good                        5.9 Crore
# 21                  Good                          6 Crore
# 22                  Good                        100 Crore
# 23                  Good                        2.4 Crore
# 24                  Good                          6 Crore
# 25                  Good                          1 Crore
# 26                   Bad                         14 Crore
# 27                   Bad                          2 Crore
# 28                   Bad                       4.32 Crore
# 29                   Bad                          6 Crore
# 30                   Bad                        1.3 Crore
# 31                   Bad                          60 lakh
# 32                   Bad                          60 lakh
# 33                   Bad                         10 Crore
# 34                   Bad                        2.3 Crore
# 35                   Bad                          2 Crore
# 36                   Bad                          1 Crore
# 37                   Bad                          5 Crore
# 38                   Bad                          2 Crore
# 39                   Bad                          2 Crore
# 40                   Bad                          6 Crore
# 41                   Bad                          2 Crore
# 42                   Bad                       1.31 Crore
# 43                   Bad                          1 Crore
# 44                   Bad                          6 Crore
# 45                   Bad                         24 Crore
# 46                   Bad                          5 Crore
# 47                   Bad                        `10 Crore
# 48                   Bad                          6 Crore
# 49                   Bad                          1 Crore
#
#     First day Box office collection.1
# 0                           330000000
# 1                            37000000
# 2                           400000000
# 3                            15000000
# 4                            50000000
# 5                           150000000
# 6                            80000000
# 7                           340000000
# 8                            80000000
# 9                           180000000
# 10                           80000000
# 11                          100000000
# 12                           80000000
# 13                          100000000
# 14                          100000000
# 15                          820000000
# 16                          330000000
# 17                           25000000
# 18                          100000000
# 19                          150000000
# 20                           59000000
# 21                           60000000
# 22                         1000000000
# 23                           24000000
# 24                           60000000
# 25                           10000000
# 26                          140000000
# 27                           20000000
# 28                           43200000
# 29                           60000000
# 30                           13000000
# 31                            6000000
# 32                            6000000
# 33                          100000000
# 34                           23000000
# 35                           20000000
# 36                           10000000
# 37                           50000000
# 38                           20000000
# 39                           20000000
# 40                           60000000
# 41                           20000000
# 42                           13100000
# 43                           10000000
# 44                           60000000
# 45                          240000000
# 46                           50000000
# 47                          100000000
# 48                           60000000
# 49                           10000000
#
# [50 rows x 37 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   S.No                               50 non-null     int64
#  1   Film Industry                      50 non-null     object
#  2   Movie Name                         50 non-null     object
#  3   Genre                              50 non-null     object
#  4   Movie Release Date                 50 non-null     object
#  5   Investment                         50 non-null     object
#  6   Investment.1                       50 non-null     int64
#  7   Profit                             50 non-null     object
#  8   Profit.1                           50 non-null     int64
#  9   Success/Failure                    50 non-null     int64
#  10  IMDb Rating                        50 non-null     float64
#  11  Trailer Released Date              50 non-null     object
#  12  YouTube Views                      50 non-null     object
#  13  YouTube Views.1                    50 non-null     int64
#  14  Common Background music            50 non-null     int64
#  15  Theme background Music             50 non-null     int64
#  16  No.of Part Released                50 non-null     int64
#  17  Comedy Scene                       50 non-null     int64
#  18  Fast mode                          50 non-null     int64
#  19  Slow mode                          50 non-null     int64
#  20  Medium mode                        50 non-null     int64
#  21  1st-30min                          50 non-null     object
#  22  2nd-30mins                         50 non-null     object
#  23  3rd-30mins                         50 non-null     object
#  24  4th-30mins                         50 non-null     object
#  25  5th-30mins                         50 non-null     object
#  26  Pre-released song views            50 non-null     object
#  27  Pre-released song views.1          50 non-null     int64
#  28  first song released date           50 non-null     object
#  29  YouTube Views.2                    50 non-null     object
#  30  YouTube Views.3                    50 non-null     int64
#  31  OTT                                50 non-null     object
#  32  Rating_Type                        50 non-null     object
#  33  Meme Marketing                     50 non-null     object
#  34  Critics_from_people                50 non-null     object
#  35  First day Box office collection    50 non-null     object
#  36  First day Box office collection.1  50 non-null     int64
# dtypes: float64(1), int64(15), object(21)
# memory usage: 14.6+ KB

# %%
quan=[]
qual=[]
for columnName in dataset.columns:
    #print(columnName)
    if(dataset[columnName].dtypes=='O'):
        #print("qual")
        qual.append(columnName)
    else:
        #print("quan")
        quan.append(columnName)

# %%
quan
# Out:
# ['S.No',
#  'Investment.1',
#  'Profit.1',
#  'Success/Failure',
#  'IMDb Rating',
#  'YouTube Views.1',
#  'Common Background music',
#  'Theme background Music',
#  'No.of Part Released',
#  'Comedy Scene',
#  'Fast mode',
#  'Slow mode',
#  'Medium mode',
#  'Pre-released song views.1',
#  'YouTube Views.3',
#  'First day Box office collection.1']

# %%
qual
# Out:
# ['Film Industry',
#  'Movie Name',
#  'Genre',
#  'Movie Release Date',
#  'Investment',
#  'Profit',
#  'Trailer Released Date',
#  'YouTube Views',
#  '1st-30min',
#  '2nd-30mins',
#  '3rd-30mins',
#  '4th-30mins',
#  '5th-30mins',
#  'Pre-released song views',
#  'first song released date',
#  'YouTube Views.2',
#  'OTT',
#  'Rating_Type',
#  'Meme Marketing',
#  'Critics_from_people ',
#  'First day Box office collection']

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
    #print(columnName)
        if(dataset[columnName].dtypes=='O'):
        #print("qual")
            qual.append(columnName)
        else:
        #print("quan")
             quan.append(columnName)
    return quan,qual

# %%
quanQual(dataset)
# Out:
# (['S.No',
#   'Investment.1',
#   'Profit.1',
#   'Success/Failure',
#   'IMDb Rating',
#   'YouTube Views.1',
#   'Common Background music',
#   'Theme background Music',
#   'No.of Part Released',
#   'Comedy Scene',
#   'Fast mode',
#   'Slow mode',
#   'Medium mode',
#   'Pre-released song views.1',
#   'YouTube Views.3',
#   'First day Box office collection.1'],
#  ['Film Industry',
#   'Movie Name',
#   'Genre',
#   'Movie Release Date',
#   'Investment',
#   'Profit',
#   'Trailer Released Date',
#   'YouTube Views',
#   '1st-30min',
#   '2nd-30mins',
#   '3rd-30mins',
#   '4th-30mins',
#   '5th-30mins',
#   'Pre-released song views',
#   'first song released date',
#   'YouTube Views.2',
#   'OTT',
#   'Rating_Type',
#   'Meme Marketing',
#   'Critics_from_people ',
#   'First day Box office collection'])

# %%
quan
# Out:
# ['S.No',
#  'Investment.1',
#  'Profit.1',
#  'Success/Failure',
#  'IMDb Rating',
#  'YouTube Views.1',
#  'Common Background music',
#  'Theme background Music',
#  'No.of Part Released',
#  'Comedy Scene',
#  'Fast mode',
#  'Slow mode',
#  'Medium mode',
#  'Pre-released song views.1',
#  'YouTube Views.3',
#  'First day Box office collection.1']

# %%
qual
# Out:
# ['Film Industry',
#  'Movie Name',
#  'Genre',
#  'Movie Release Date',
#  'Investment',
#  'Profit',
#  'Trailer Released Date',
#  'YouTube Views',
#  '1st-30min',
#  '2nd-30mins',
#  '3rd-30mins',
#  '4th-30mins',
#  '5th-30mins',
#  'Pre-released song views',
#  'first song released date',
#  'YouTube Views.2',
#  'OTT',
#  'Rating_Type',
#  'Meme Marketing',
#  'Critics_from_people ',
#  'First day Box office collection']

# %%
dataset.describe()
# Out:
#            S.No  Investment.1      Profit.1  Success/Failure  IMDb Rating  \
# count  50.00000  5.000000e+01  5.000000e+01        50.000000    50.000000
# mean   25.50000  7.856600e+08  1.081400e+09         0.500000     6.440000
# std    14.57738  1.205034e+09  1.583824e+09         0.505076     1.797277
# min     1.00000  8.000000e+06  8.000000e+07         0.000000     2.800000
# 25%    13.25000  2.050000e+08  2.225000e+08         0.000000     4.850000
# 50%    25.50000  4.000000e+08  4.700000e+08         0.500000     6.900000
# 75%    37.75000  7.000000e+08  1.015000e+09         1.000000     8.000000
# max    50.00000  6.000000e+09  8.000000e+09         1.000000     9.400000
#
#        YouTube Views.1  Common Background music  Theme background Music  \
# count     5.000000e+01                50.000000               50.000000
# mean      1.095406e+07                 0.540000                0.480000
# std       1.446529e+07                 0.503457                0.504672
# min       6.800000e+04                 0.000000                0.000000
# 25%       5.617500e+05                 0.000000                0.000000
# 50%       5.250000e+06                 1.000000                0.000000
# 75%       1.400000e+07                 1.000000                1.000000
# max       5.900000e+07                 1.000000                1.000000
#
#        No.of Part Released  Comedy Scene  Fast mode  Slow mode  Medium mode  \
# count            50.000000          50.0   50.00000  50.000000    50.000000
# mean              3.520000           1.0    0.14000   0.040000     0.820000
# std               0.735125           0.0    0.35051   0.197949     0.388088
# min               2.000000           1.0    0.00000   0.000000     0.000000
# 25%               3.000000           1.0    0.00000   0.000000     1.000000
# 50%               3.000000           1.0    0.00000   0.000000     1.000000
# 75%               4.000000           1.0    0.00000   0.000000     1.000000
# max               5.000000           1.0    1.00000   1.000000     1.000000
#
#        Pre-released song views.1  YouTube Views.3  \
# count               5.000000e+01     5.000000e+01
# mean                1.431362e+07     2.974226e+07
# std                 2.605552e+07     6.375571e+07
# min                 1.200000e+04     1.290000e+04
# 25%                 1.000000e+06     3.050000e+06
# 50%                 2.050000e+06     9.150000e+06
# 75%                 1.600000e+07     2.975000e+07
# max                 1.120000e+08     4.060000e+08
#
#        First day Box office collection.1
# count                       5.000000e+01
# mean                        1.182860e+08
# std                         1.888205e+08
# min                         6.000000e+06
# 25%                         2.000000e+07
# 50%                         6.000000e+07
# 75%                         1.000000e+08
# max                         1.000000e+09

# %%
descriptive=pd.DataFrame()
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)

# %%
descriptive
# Out:
#        S.No Investment.1 Profit.1 Success/Failure IMDb Rating YouTube Views.1  \
# Mean    NaN          NaN      NaN             NaN         NaN             NaN
# Median  NaN          NaN      NaN             NaN         NaN             NaN
# Mode    NaN          NaN      NaN             NaN         NaN             NaN
#
#        Common Background music Theme background Music No.of Part Released  \
# Mean                       NaN                    NaN                 NaN
# Median                     NaN                    NaN                 NaN
# Mode                       NaN                    NaN                 NaN
#
#        Comedy Scene Fast mode Slow mode Medium mode Pre-released song views.1  \
# Mean            NaN       NaN       NaN         NaN                       NaN
# Median          NaN       NaN       NaN         NaN                       NaN
# Mode            NaN       NaN       NaN         NaN                       NaN
#
#        YouTube Views.3 First day Box office collection.1
# Mean               NaN                               NaN
# Median             NaN                               NaN
# Mode               NaN                               NaN

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]

# %%
descriptive
# Out:
#         S.No Investment.1      Profit.1 Success/Failure IMDb Rating  \
# Mean    25.5  785660000.0  1081400000.0             0.5        6.44
# Median  25.5  400000000.0   470000000.0             0.5         6.9
# Mode       1    400000000    1000000000               0         8.0
#
#        YouTube Views.1 Common Background music Theme background Music  \
# Mean        10954060.0                    0.54                   0.48
# Median       5250000.0                     1.0                    0.0
# Mode          10000000                       1                      0
#
#        No.of Part Released Comedy Scene Fast mode Slow mode Medium mode  \
# Mean                  3.52          1.0      0.14      0.04        0.82
# Median                 3.0          1.0       0.0       0.0         1.0
# Mode                     3            1         0         0           1
#
#        Pre-released song views.1 YouTube Views.3  \
# Mean                  14313620.0      29742258.0
# Median                 2050000.0       9150000.0
# Mode                     2000000        50000000
#
#        First day Box office collection.1
# Mean                         118286000.0
# Median                        60000000.0
# Mode                            60000000

# %%
import numpy as np

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]- descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Min"]=dataset[columnName].min()
    descriptive[columnName]["Max"]=dataset[columnName].max()

# %%
descriptive
# Out:
#           S.No       Investment.1           Profit.1 Success/Failure  \
# Mean      25.5        785660000.0       1081400000.0             0.5
# Median    25.5        400000000.0        470000000.0             0.5
# Mode         1          400000000         1000000000               0
# Q1:25%   13.25        205000000.0        222500000.0             0.0
# Q2:50%    25.5        400000000.0        470000000.0             0.5
# Q3:75%   37.75        700000000.0       1015000000.0             1.0
# 99%      49.51  5509999999.999998  7264999999.999997             1.0
# Q4:100%   50.0       6000000000.0       8000000000.0             1.0
# IQR       24.5        495000000.0        792500000.0             1.0
# 1.5rule  36.75        742500000.0       1188750000.0             1.5
# Lesser   -23.5       -537500000.0       -966250000.0            -1.5
# Greater   74.5       1442500000.0       2203750000.0             2.5
# Min          1            8000000           80000000               0
# Max         50         6000000000         8000000000               1
#
#         IMDb Rating YouTube Views.1 Common Background music  \
# Mean           6.44      10954060.0                    0.54
# Median          6.9       5250000.0                     1.0
# Mode            8.0        10000000                       1
# Q1:25%         4.85        561750.0                     0.0
# Q2:50%          6.9       5250000.0                     1.0
# Q3:75%          8.0      14000000.0                     1.0
# 99%           9.155      59000000.0                     1.0
# Q4:100%         9.4      59000000.0                     1.0
# IQR            3.15      13438250.0                     1.0
# 1.5rule       4.725      20157375.0                     1.5
# Lesser        0.125     -19595625.0                    -1.5
# Greater      12.725      34157375.0                     2.5
# Min             2.8           68000                       0
# Max             9.4        59000000                       1
#
#         Theme background Music No.of Part Released Comedy Scene Fast mode  \
# Mean                      0.48                3.52          1.0      0.14
# Median                     0.0                 3.0          1.0       0.0
# Mode                         0                   3            1         0
# Q1:25%                     0.0                 3.0          1.0       0.0
# Q2:50%                     0.0                 3.0          1.0       0.0
# Q3:75%                     1.0                 4.0          1.0       0.0
# 99%                        1.0                 5.0          1.0       1.0
# Q4:100%                    1.0                 5.0          1.0       1.0
# IQR                        1.0                 1.0          0.0       0.0
# 1.5rule                    1.5                 1.5          0.0       0.0
# Lesser                    -1.5                 1.5          1.0       0.0
# Greater                    2.5                 5.5          1.0       0.0
# Min                          0                   2            1         0
# Max                          1                   5            1         1
#
#         Slow mode Medium mode Pre-released song views.1 YouTube Views.3  \
# Mean         0.04        0.82                14313620.0      29742258.0
# Median        0.0         1.0                 2050000.0       9150000.0
# Mode            0           1                   2000000        50000000
# Q1:25%        0.0         1.0                 1000000.0       3050000.0
# Q2:50%        0.0         1.0                 2050000.0       9150000.0
# Q3:75%        0.0         1.0                16000000.0      29750000.0
# 99%           1.0         1.0               105140000.0     302610000.0
# Q4:100%       1.0         1.0               112000000.0     406000000.0
# IQR           0.0         0.0                15000000.0      26700000.0
# 1.5rule       0.0         0.0                22500000.0      40050000.0
# Lesser        0.0         1.0               -21500000.0     -37000000.0
# Greater       0.0         1.0                38500000.0      69800000.0
# Min             0           0                     12000           12900
# Max             1           1                 112000000       406000000
#
#         First day Box office collection.1
# Mean                          118286000.0
# Median                         60000000.0
# Mode                             60000000
# Q1:25%                         20000000.0
# Q2:50%                         60000000.0
# Q3:75%                        100000000.0
# 99%                           911800000.0
# Q4:100%                      1000000000.0
# IQR                            80000000.0
# 1.5rule                       120000000.0
# Lesser                       -100000000.0
# Greater                       220000000.0
# Min                               6000000
# Max                            1000000000

# %%
lesser=[]
greater=[]
for colunName in quan:
    if(descriptive[colunName]["Min"]<descriptive[colunName]["Lesser"]):
        lesser.append(colunName)
    if(descriptive[colunName]["Max"]>descriptive[colunName]["Greater"]):
        greater.append(colunName)

# %%
lesser
# Out:
# ['Medium mode']

# %%
greater
# Out:
# ['Investment.1',
#  'Profit.1',
#  'YouTube Views.1',
#  'Fast mode',
#  'Slow mode',
#  'Pre-released song views.1',
#  'YouTube Views.3',
#  'First day Box office collection.1']

# %%
for columnName in lesser:
    dataset[columnName][dataset[columnName]<descriptive[colunName]["Lesser"]]=descriptive[colunName]["Lesser"]
for columnName in greater:
    dataset[columnName][dataset[columnName]>descriptive[colunName]["Greater"]]=descriptive[colunName]["Greater"]

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]- descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Min"]=dataset[columnName].min()
    descriptive[columnName]["Max"]=dataset[columnName].max()

# %%
descriptive
# Out:
#           S.No Investment.1     Profit.1 Success/Failure IMDb Rating  \
# Mean      25.5  220000000.0  220000000.0             0.5        6.44
# Median    25.5  220000000.0  220000000.0             0.5         6.9
# Mode         1    220000000    220000000               0         8.0
# Q1:25%   13.25  220000000.0  220000000.0             0.0        4.85
# Q2:50%    25.5  220000000.0  220000000.0             0.5         6.9
# Q3:75%   37.75  220000000.0  220000000.0             1.0         8.0
# 99%      49.51  220000000.0  220000000.0             1.0       9.155
# Q4:100%   50.0  220000000.0  220000000.0             1.0         9.4
# IQR       24.5          0.0          0.0             1.0        3.15
# 1.5rule  36.75          0.0          0.0             1.5       4.725
# Lesser   -23.5  220000000.0  220000000.0            -1.5       0.125
# Greater   74.5  220000000.0  220000000.0             2.5      12.725
# Min          1    220000000    220000000               0         2.8
# Max         50    220000000    220000000               1         9.4
#
#         YouTube Views.1 Common Background music Theme background Music  \
# Mean        220000000.0                    0.54                   0.48
# Median      220000000.0                     1.0                    0.0
# Mode          220000000                       1                      0
# Q1:25%      220000000.0                     0.0                    0.0
# Q2:50%      220000000.0                     1.0                    0.0
# Q3:75%      220000000.0                     1.0                    1.0
# 99%         220000000.0                     1.0                    1.0
# Q4:100%     220000000.0                     1.0                    1.0
# IQR                 0.0                     1.0                    1.0
# 1.5rule             0.0                     1.5                    1.5
# Lesser      220000000.0                    -1.5                   -1.5
# Greater     220000000.0                     2.5                    2.5
# Min           220000000                       0                      0
# Max           220000000                       1                      1
#
#         No.of Part Released Comedy Scene    Fast mode    Slow mode  \
# Mean                   3.52          1.0  220000000.0  220000000.0
# Median                  3.0          1.0  220000000.0  220000000.0
# Mode                      3            1    220000000    220000000
# Q1:25%                  3.0          1.0  220000000.0  220000000.0
# Q2:50%                  3.0          1.0  220000000.0  220000000.0
# Q3:75%                  4.0          1.0  220000000.0  220000000.0
# 99%                     5.0          1.0  220000000.0  220000000.0
# Q4:100%                 5.0          1.0  220000000.0  220000000.0
# IQR                     1.0          0.0          0.0          0.0
# 1.5rule                 1.5          0.0          0.0          0.0
# Lesser                  1.5          1.0  220000000.0  220000000.0
# Greater                 5.5          1.0  220000000.0  220000000.0
# Min                       2            1    220000000    220000000
# Max                       5            1    220000000    220000000
#
#          Medium mode Pre-released song views.1 YouTube Views.3  \
# Mean    -100000000.0               220000000.0     220000000.0
# Median  -100000000.0               220000000.0     220000000.0
# Mode      -100000000                 220000000       220000000
# Q1:25%  -100000000.0               220000000.0     220000000.0
# Q2:50%  -100000000.0               220000000.0     220000000.0
# Q3:75%  -100000000.0               220000000.0     220000000.0
# 99%     -100000000.0               220000000.0     220000000.0
# Q4:100% -100000000.0               220000000.0     220000000.0
# IQR              0.0                       0.0             0.0
# 1.5rule          0.0                       0.0             0.0
# Lesser  -100000000.0               220000000.0     220000000.0
# Greater -100000000.0               220000000.0     220000000.0
# Min       -100000000                 220000000       220000000
# Max       -100000000                 220000000       220000000
#
#         First day Box office collection.1
# Mean                          220000000.0
# Median                        220000000.0
# Mode                            220000000
# Q1:25%                        220000000.0
# Q2:50%                        220000000.0
# Q3:75%                        220000000.0
# 99%                           220000000.0
# Q4:100%                       220000000.0
# IQR                                   0.0
# 1.5rule                               0.0
# Lesser                        220000000.0
# Greater                       220000000.0
# Min                             220000000
# Max                             220000000

# %%
lesser=[]
greater=[]
for colunName in quan:
    if(descriptive[colunName]["Min"]<descriptive[colunName]["Lesser"]):
        lesser.append(colunName)
    if(descriptive[colunName]["Max"]>descriptive[colunName]["Greater"]):
        greater.append(colunName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
freqTable=pd.DataFrame(columns=["Unique_Values","Frequency","Relative Frequency","cusum"])

# %%
freqTable
# Out:
# Empty DataFrame
# Columns: [Unique_Values, Frequency, Relative Frequency, cusum]
# Index: []

# %%
def freqTable(colunName,dataset):
    freqTable=pd.DataFrame(columns=["Unique_Values","Frequency","Relative Frequency","cusum"])
    freqTable["Unique_Values"]=dataset[columnName].value_counts().index
    freqTable["Frequency"]=dataset[columnName].value_counts().values
    freqTable["Relative Frequency"]=(freqTable["Frequency"]/103)
    freqTable["cusum"]=freqTable["Relative Frequency"].cumsum()
    return freqTable

# %%
freqTable("hsc_p",dataset)
# Out:
#     Unique_Values  Frequency  Relative Frequency     cusum
# 0       220000000          7            0.067961  0.067961
# 1       100000000          6            0.058252  0.126214
# 2        60000000          6            0.058252  0.184466
# 3        20000000          5            0.048544  0.233010
# 4        80000000          4            0.038835  0.271845
# 5        10000000          4            0.038835  0.310680
# 6        50000000          3            0.029126  0.339806
# 7         6000000          2            0.019417  0.359223
# 8       150000000          2            0.019417  0.378641
# 9       140000000          1            0.009709  0.388350
# 10       23000000          1            0.009709  0.398058
# 11       13000000          1            0.009709  0.407767
# 12       43200000          1            0.009709  0.417476
# 13       24000000          1            0.009709  0.427184
# 14       37000000          1            0.009709  0.436893
# 15       59000000          1            0.009709  0.446602
# 16       25000000          1            0.009709  0.456311
# 17       15000000          1            0.009709  0.466019
# 18      180000000          1            0.009709  0.475728
# 19       13100000          1            0.009709  0.485437

# %%
def Univariate(dataset,quan):
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max","kurtosis","skewness","var","std"],columns=quan)
    for columnName in quan:
        descriptive[columnName]["Mean"]=dataset[columnName].mean()
        descriptive[columnName]["Median"]=dataset[columnName].median()
        descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
        descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]- descriptive[columnName]["Q1:25%"]
        descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
        descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
        descriptive[columnName]["Greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
        descriptive[columnName]["Min"]=dataset[columnName].min()
        descriptive[columnName]["Max"]=dataset[columnName].max()
        descriptive[columnName]["kurtosis"]=dataset[columnName].kurtosis()
        descriptive[columnName]["skewness"]=dataset[columnName].skew()
        descriptive[columnName]["var"]=dataset[columnName].var()
        descriptive[columnName]["std"]=dataset[columnName].std()    
    return descriptive

# %%
Univariate(dataset,quan)
# Out:
#               S.No        Investment.1             Profit.1 Success/Failure  \
# Mean          25.5         191060000.0          198400000.0             0.5
# Median        25.5         220000000.0          220000000.0             0.5
# Mode             1           220000000            220000000               0
# Q1:25%       13.25         205000000.0          220000000.0             0.0
# Q2:50%        25.5         220000000.0          220000000.0             0.5
# Q3:75%       37.75         220000000.0          220000000.0             1.0
# 99%          49.51         220000000.0          220000000.0             1.0
# Q4:100%       50.0         220000000.0          220000000.0             1.0
# IQR           24.5          15000000.0                  0.0             1.0
# 1.5rule      36.75          22500000.0                  0.0             1.5
# Lesser       -23.5         182500000.0          220000000.0            -1.5
# Greater       74.5         242500000.0          220000000.0             2.5
# Min              1             8000000             80000000               0
# Max             50           220000000            220000000               1
# kurtosis      -1.2            3.240471             1.457253       -2.085106
# skewness       0.0           -2.106695            -1.727611             0.0
# var          212.5  3718220816326530.5  1813714285714285.75        0.255102
# std       14.57738     60977215.550782      42587724.589537        0.505076
#
#          IMDb Rating       YouTube Views.1 Common Background music  \
# Mean            6.44            10954060.0                    0.54
# Median           6.9             5250000.0                     1.0
# Mode             8.0              10000000                       1
# Q1:25%          4.85              561750.0                     0.0
# Q2:50%           6.9             5250000.0                     1.0
# Q3:75%           8.0            14000000.0                     1.0
# 99%            9.155            59000000.0                     1.0
# Q4:100%          9.4            59000000.0                     1.0
# IQR             3.15            13438250.0                     1.0
# 1.5rule        4.725            20157375.0                     1.5
# Lesser         0.125           -19595625.0                    -1.5
# Greater       12.725            34157375.0                     2.5
# Min              2.8                 68000                       0
# Max              9.4              59000000                       1
# kurtosis   -1.055811              3.915728               -2.056566
# skewness    -0.38204              1.997987               -0.165522
# var         3.230204  209244535077959.1875                0.253469
# std         1.797277       14465287.244917                0.503457
#
#          Theme background Music No.of Part Released Comedy Scene Fast mode  \
# Mean                       0.48                3.52          1.0      0.14
# Median                      0.0                 3.0          1.0       0.0
# Mode                          0                   3            1         0
# Q1:25%                      0.0                 3.0          1.0       0.0
# Q2:50%                      0.0                 3.0          1.0       0.0
# Q3:75%                      1.0                 4.0          1.0       0.0
# 99%                         1.0                 5.0          1.0       1.0
# Q4:100%                     1.0                 5.0          1.0       1.0
# IQR                         1.0                 1.0          0.0       0.0
# 1.5rule                     1.5                 1.5          0.0       0.0
# Lesser                     -1.5                 1.5          1.0       0.0
# Greater                     2.5                 5.5          1.0       0.0
# Min                           0                   2            1         0
# Max                           1                   5            1         1
# kurtosis              -2.078006           -0.272745            0  2.684315
# skewness               0.082562            0.731014            0   2.13974
# var                    0.254694            0.540408          0.0  0.122857
# std                    0.504672            0.735125          0.0   0.35051
#
#           Slow mode Medium mode Pre-released song views.1  \
# Mean           0.04        0.82                14313620.0
# Median          0.0         1.0                 2050000.0
# Mode              0           1                   2000000
# Q1:25%          0.0         1.0                 1000000.0
# Q2:50%          0.0         1.0                 2050000.0
# Q3:75%          0.0         1.0                16000000.0
# 99%             1.0         1.0               105140000.0
# Q4:100%         1.0         1.0               112000000.0
# IQR             0.0         0.0                15000000.0
# 1.5rule         0.0         0.0                22500000.0
# Lesser          0.0         1.0               -21500000.0
# Greater         0.0         1.0                38500000.0
# Min               0           0                     12000
# Max               1           1                 112000000
# kurtosis  22.330729    0.988872                  6.616638
# skewness   4.841323   -1.717824                  2.618622
# var        0.039184    0.150612       678890064893469.375
# std        0.197949    0.388088           26055518.895111
#
#               YouTube Views.3 First day Box office collection.1
# Mean               26022258.0                        79886000.0
# Median              9150000.0                        60000000.0
# Mode                 50000000                         220000000
# Q1:25%              3050000.0                        20000000.0
# Q2:50%              9150000.0                        60000000.0
# Q3:75%             29750000.0                       100000000.0
# 99%               207750000.0                       220000000.0
# Q4:100%           220000000.0                       220000000.0
# IQR                26700000.0                        80000000.0
# 1.5rule            40050000.0                       120000000.0
# Lesser            -37000000.0                      -100000000.0
# Greater            69800000.0                       220000000.0
# Min                     12900                           6000000
# Max                 220000000                         220000000
# kurtosis            11.352716                         -0.211564
# skewness             3.198894                          0.993405
# var       1900223741866974.75                4957044902040816.0
# std           43591555.855085                   70406284.535124
